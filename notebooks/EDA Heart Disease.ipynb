# %% [markdown]
# # Heart Disease Predictor

# %% [markdown]
# #### Life cycle of Machine learning Project
#
# - Understanding the Problem Statement
# - Data Collection
# - Data Checks to perform
# - Exploratory data analysis
# - Data Pre-Processing
# - Model Training
# - Choose best model

# %% [markdown]
# ### 1) Background:
# - Cardiovascular diseases are a leading cause of mortality worldwide, with heart disease being a significant contributor to premature deaths. Early detection and accurate prediction of heart disease can enable timely medical interventions, improving patient outcomes and reducing healthcare costs. The  dataset, contains a comprehensive set of features related to demographic, lifestyle, and clinical factors that may influence the likelihood of heart disease. These features include age, gender, blood pressure, cholesterol levels, exercise habits, smoking status, family history of heart disease, diabetes, BMI, and various biomarkers such as triglyceride levels, fasting blood sugar, CRP, and homocysteine levels, along with the target variable indicating heart disease status.
#
#
# ### 2) Problem statement
# - The objective of this machine learning project is to develop a predictive model that accurately identifies individuals at risk of heart disease based on the features provided in the "heart_disease.csv" dataset. The model will classify individuals into two categories: those with heart disease (Yes) and those without heart disease (No). By leveraging demographic, lifestyle, and clinical data, the model aims to assist healthcare professionals in early diagnosis, risk stratification, and personalized treatment planning for patients. The challenge lies in handling a mix of numerical (e.g., age, blood pressure, cholesterol levels) and categorical (e.g., gender, smoking status, exercise habits) features, addressing potential missing or noisy data, and selecting the most relevant features to improve model performance while avoiding overfitting.
#
#
# ### 3) Data Collection
# - Dataset Source - https://www.kaggle.com/datasets/oktayrdeki/heart-disease
# - The data consists of 21 column and 10000 rows.
#
# ### 4) Expected Impact
# - The successful development of this predictive model will enable early identification of individuals at high risk of heart disease, facilitating preventive measures and targeted interventions. This can lead to improved patient outcomes, reduced healthcare costs, and a better understanding of the risk factors associated with heart disease, ultimately contributing to public health advancements.

# %% [markdown]
# ### 2.1 Import Data and Required Packages
# ####  Importing Pandas, Numpy, Matplotlib, Seaborn and Warings Library.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Import the CSV Data as Pandas DataFrame

# %%
df = pd.read_csv('data\heart_disease.csv')

# %% [markdown]
# #### Show Top 5 Records

# %%
df.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# ...

# %% [markdown]
# #### Shape of the dataset

# %%
df.shape
# Out:
# (10000, 21)

# %% [markdown]
# ### 2.2 Dataset information

# %% [markdown]
# - Age: The individual's age.
#
# - Gender: The individual's gender (Male or Female).
#
# - Blood Pressure: The individual's blood pressure (systolic).
#
# - Cholesterol Level: The individual's total cholesterol level.
#
# - Exercise Habits: The individual's exercise habits (Low, Medium, High).
#
# - Smoking: Whether the individual smokes or not (Yes or No).
#
# - Family Heart Disease: Whether there is a family history of heart disease (Yes or No).
#
# - Diabetes: Whether the individual has diabetes (Yes or No).
#
# - BMI: The individual's body mass index.
#
# - High Blood Pressure: Whether the individual has high blood pressure (Yes or No).
#
# - Low HDL Cholesterol: Whether the individual has low HDL cholesterol (Yes or No).
#
# - High LDL Cholesterol: Whether the individual has high LDL cholesterol (Yes or No).
#
# - Alcohol Consumption: The individual's alcohol consumption level (None, Low, Medium, High).
#
# - Stress Level: The individual's stress level (Low, Medium, High).
#
# - Sleep Hours: The number of hours the individual sleeps.
#
# - Sugar Consumption: The individual's sugar consumption level (Low, Medium, High).
#
# - Triglyceride Level: The individual's triglyceride level.
#
# - Fasting Blood Sugar: The individual's fasting blood sugar level.
#
# - CRP Level: The C-reactive protein level (a marker of inflammation).
#
# - Homocysteine Level: The individual's homocysteine level (an amino acid that affects blood vessel health).
#
# - Heart Disease Status: The individual's heart disease status (Yes or No).

# %% [markdown]
# ### 3. Data Checks to perform
#
# - Check Missing values
# - Check Duplicates
# - Check data type
# - Check the number of unique values of each column
# - Check statistics of data set
# - Check various categories present in the different categorical column

# %% [markdown]
# ### 3.1 Check Missing values

# %%
df.isna().sum()
# Out:
# Age                       29
# Gender                    19
# Blood Pressure            19
# Cholesterol Level         30
# Exercise Habits           25
# Smoking                   25
# Family Heart Disease      21
# Diabetes                  30
# BMI                       22
# High Blood Pressure       26
# Low HDL Cholesterol       25
# High LDL Cholesterol      26
# Alcohol Consumption     2586
# Stress Level              22
# Sleep Hours               25
# Sugar Consumption         30
# Triglyceride Level        26
# Fasting Blood Sugar       22
# CRP Level                 26
# Homocysteine Level        20
# Heart Disease Status       0
# dtype: int64

# %% [markdown]
# #### There are missing values in the data set

# %% [markdown]
# ### 3.2 Check Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### There are no Duplicate values

# %% [markdown]
# ### 3.3 Check data types

# %%
# Check Null and Dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   9971 non-null   float64
#  1   Gender                9981 non-null   object
#  2   Blood Pressure        9981 non-null   float64
#  3   Cholesterol Level     9970 non-null   float64
#  4   Exercise Habits       9975 non-null   object
#  5   Smoking               9975 non-null   object
#  6   Family Heart Disease  9979 non-null   object
#  7   Diabetes              9970 non-null   object
#  8   BMI                   9978 non-null   float64
#  9   High Blood Pressure   9974 non-null   object
#  10  Low HDL Cholesterol   9975 non-null   object
#  11  High LDL Cholesterol  9974 non-null   object
#  12  Alcohol Consumption   7414 non-null   object
#  13  Stress Level          9978 non-null   object
# ...

# %% [markdown]
# ### 3.4 Checking the number of unique values of each column

# %%
df.nunique()
# Out:
# Age                       63
# Gender                     2
# Blood Pressure            61
# Cholesterol Level        151
# Exercise Habits            3
# Smoking                    2
# Family Heart Disease       2
# Diabetes                   2
# BMI                     9978
# High Blood Pressure        2
# Low HDL Cholesterol        2
# High LDL Cholesterol       2
# Alcohol Consumption        3
# Stress Level               3
# Sleep Hours             9975
# Sugar Consumption          3
# Triglyceride Level       301
# Fasting Blood Sugar       81
# CRP Level               9974
# Homocysteine Level      9980
# Heart Disease Status       2
# dtype: int64

# %% [markdown]
# ### 3.5 Check statistics of data set

# %%
df.describe()
# Out:
#                Age  Blood Pressure  Cholesterol Level          BMI  \
# count  9971.000000     9981.000000        9970.000000  9978.000000
# mean     49.296259      149.757740         225.425577    29.077269
# std      18.193970       17.572969          43.575809     6.307098
# min      18.000000      120.000000         150.000000    18.002837
# 25%      34.000000      134.000000         187.000000    23.658075
# 50%      49.000000      150.000000         226.000000    29.079492
# 75%      65.000000      165.000000         263.000000    34.520015
# max      80.000000      180.000000         300.000000    39.996954
#
#        Sleep Hours  Triglyceride Level  Fasting Blood Sugar    CRP Level  \
# count  9975.000000         9974.000000          9978.000000  9974.000000
# mean      6.991329          250.734409           120.142213     7.472201
# std       1.753195           87.067226            23.584011     4.340248
# ...

# %% [markdown]
# ### Insights
#
# - The dataset shows a population with multiple risk factors for heart disease: high blood pressure (mean 149.76 mmHg), elevated cholesterol (mean 225.43 mg/dL), high triglycerides (mean 250.73 mg/dL), elevated fasting blood sugar (mean 120.14 mg/dL), and high BMI (mean 29.08).
#
# - Inflammation markers like CRP (mean 7.47 mg/L) and homocysteine (mean 12.46 µmol/L) are also elevated, further increasing cardiovascular risk.
#
# - Sleep hours are generally adequate (mean 6.99), but a notable portion sleeps less than recommended, which could contribute to health issues.
#
# - The wide age range (18–80) suggests these risk factors are present across different age groups, with older individuals (75% are 65 or younger) potentially at higher risk due to age-related factors.

# %% [markdown]
# ### 3.7 Exploring Data

# %%
df.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# ...

# %% [markdown]
# ### Define numerical and categorical columns

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 9 numerical features : ['Age', 'Blood Pressure', 'Cholesterol Level', 'BMI', 'Sleep Hours', 'Triglyceride Level', 'Fasting Blood Sugar', 'CRP Level', 'Homocysteine Level']
#
# We have 12 categorical features : ['Gender', 'Exercise Habits', 'Smoking', 'Family Heart Disease', 'Diabetes', 'High Blood Pressure', 'Low HDL Cholesterol', 'High LDL Cholesterol', 'Alcohol Consumption', 'Stress Level', 'Sugar Consumption', 'Heart Disease Status']

# %% [markdown]
# ### Unique Categorical values

# %%
# Print unique categories for selected categorical variables
print("Categories in 'Gender' variable:     ", end=" ")
print(df['Gender'].unique())

print("Categories in 'Smoking' variable:  ", end=" ")
print(df['Smoking'].unique())

print("Categories in 'Diabetes' variable: ", end=" ")
print(df['Diabetes'].unique())

print("Categories in 'Exercise Habits' variable:     ", end=" ")
print(df['Exercise Habits'].unique())

print("Categories in 'Heart Disease Status' variable:     ", end=" ")
print(df['Heart Disease Status'].unique())

print("Categories in 'Family Heart Disease' variable:     ", end=" ")
print(df['Family Heart Disease'].unique())

print("Categories in 'High Blood Pressure' variable:     ", end=" ")
print(df['High Blood Pressure'].unique())

print("Categories in 'Sugar Consumption' variable:     ", end=" ")
print(df['Sugar Consumption'].unique())

print("Categories in 'Stress Level' variable:     ", end=" ")
print(df['Stress Level'].unique())

print("Categories in 'Alcohol Consumption' variable:     ", end=" ")
print(df['Alcohol Consumption'].unique())

print("Categories in 'Low HDL Cholesterol' variable:     ", end=" ")
print(df['Low HDL Cholesterol'].unique())

print("Categories in 'High LDL Cholesterol' variable:     ", end=" ")
print(df['High LDL Cholesterol'].unique())
# Out:
# Categories in 'Gender' variable:      ['Male' 'Female' nan]
# Categories in 'Smoking' variable:   ['Yes' 'No' nan]
# Categories in 'Diabetes' variable:  ['No' 'Yes' nan]
# Categories in 'Exercise Habits' variable:      ['High' 'Low' 'Medium' nan]
# Categories in 'Heart Disease Status' variable:      ['No' 'Yes']
# Categories in 'Family Heart Disease' variable:      ['Yes' 'No' nan]
# Categories in 'High Blood Pressure' variable:      ['Yes' 'No' nan]
# Categories in 'Sugar Consumption' variable:      ['Medium' 'Low' 'High' nan]
# Categories in 'Stress Level' variable:      ['Medium' 'High' 'Low' nan]
# Categories in 'Alcohol Consumption' variable:      ['High' 'Medium' 'Low' nan]
# Categories in 'Low HDL Cholesterol' variable:      ['Yes' 'No' nan]
# Categories in 'High LDL Cholesterol' variable:      ['No' 'Yes' nan]

# %%
df.head(2)
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# 0                   No                High       Medium    7.633228
# 1                   No              Medium         High    8.744034
#
#    Sugar Consumption Triglyceride Level  Fasting Blood Sugar  CRP Level  \
# 0             Medium              342.0                  NaN  12.969246
# 1             Medium              133.0                157.0   9.355389
#
#    Homocysteine Level  Heart Disease Status
# 0           12.387250                    No
# ...

# %% [markdown]
# ### 4. Exploring Data ( Visualization )
# #### 4.1 Visualize average score distribution to make some conclusion.
# - Histogram

# %% [markdown]
# #### 4.1.1 Histogram

# %%
# Visualization 1: Histogram of Age Distribution
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x="Age", bins=10, color="#ea3453")
plt.title("Age Distribution", fontsize=16)
plt.xlabel("Age (Years)", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.1.2 BarChart

# %%
# Visualization 2: Bar Chart for Smoking vs Heart Disease
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x="Smoking", hue="Heart Disease Status", palette={"Yes": "#ef4444", "No": "#10b981"})
plt.title("Smoking and Heart Disease", fontsize=16)
plt.xlabel("Smoking Status", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.legend(title="Heart Disease")
plt.tight_layout()
plt.show()

# %%
# Visualization 4: Box Plot for Sleep Hours vs Heart Disease (Interesting Fact)
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x="Heart Disease Status", y="Sleep Hours", palette={"Yes": "#ef4444", "No": "#10b981"})
plt.title("Sleep Hours by Heart Disease Status", fontsize=16)
plt.xlabel("Heart Disease Status", fontsize=12)
plt.ylabel("Sleep Hours", fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Visualization 5: Interactive Scatter Plot with Plotly
# We'll create a scatter plot of Age vs Cholesterol Level, colored by Heart Disease Status
import plotly.express as px
fig = px.scatter(
    df,
    x="Age",
    y="Cholesterol Level",
    color="Heart Disease Status",
    color_discrete_map={"Yes": "#ef4444", "No": "#10b981"},
    title="Interactive Scatter Plot: Age vs Cholesterol Level",
    labels={"Age": "Age (Years)", "Cholesterol Level": "Cholesterol Level (mg/dL)"},
    hover_data=["BMI", "Fasting Blood Sugar"],
)
fig.update_layout(
    width=800,
    height=600,
    title_font_size=16,
    xaxis_title_font_size=12,
    yaxis_title_font_size=12,
)
fig.show()

# %% [markdown]
# ## Conclusion:
# - The age distribution shows a wide range (18-80 years), with most individuals between 30-70 years.
# - Smoking appears more prevalent among those with heart disease, suggesting a potential risk factor.
# - Individuals with heart disease tend to have slightly higher cholesterol levels, as seen in the box plot.
# - An interesting finding: those with heart disease sleep slightly less on average (median ~6.5 hours vs ~7 hours for those without).
# - The interactive scatter plot allows exploration of relationships, e.g., Age vs Cholesterol, with points colored by heart disease status.
